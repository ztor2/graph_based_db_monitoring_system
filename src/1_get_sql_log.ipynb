# %%
import pandas as pd
import warnings; warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('agaudit-2024-02-21-00-00-00.csv', header=None)
data.head()
# Out:
#                             0      1          2      3                    4   \
# 0  2024-02-21 09:08:02.525 KST  ags14  dvdrental  84607  192.168.16.16:58564
# 1  2024-02-21 09:08:02.525 KST  ags14  dvdrental  84607  192.168.16.16:58564
# 2  2024-02-21 09:08:30.228 KST  ags14  dvdrental  84629  192.168.16.16:58566
# 3  2024-02-21 09:08:30.228 KST  ags14  dvdrental  84629  192.168.16.16:58566
# 4  2024-02-21 09:08:30.228 KST  ags14  dvdrental  84629  192.168.16.16:58566
#
#                5   6       7                        8        9   ...  20  21  \
# 0  65d53ee2.14a7f   1   BEGIN  2024-02-21 09:08:02 KST  3/13856  ... NaN NaN
# 1  65d53ee2.14a7f   2  SELECT  2024-02-21 09:08:02 KST  3/13856  ... NaN NaN
# 2  65d53efe.14a95   1   BEGIN  2024-02-21 09:08:30 KST    4/747  ... NaN NaN
# 3  65d53efe.14a95   2  SELECT  2024-02-21 09:08:30 KST    4/747  ... NaN NaN
# 4  65d53efe.14a95   3  SELECT  2024-02-21 09:08:30 KST    4/747  ... NaN NaN
#
# ...

# %%
f1 = data.iloc[:, [8,1,2,7,27,13]]
f1.dropna(subset=[13], inplace=True)
f1 = f1[f1.iloc[:, 4] == 'READ']
f1
# Out:
#                            8      1          2       7     27  \
# 1     2024-02-21 09:08:02 KST  ags14  dvdrental  SELECT  READ
# 3     2024-02-21 09:08:30 KST  ags14  dvdrental  SELECT  READ
# 4     2024-02-21 09:08:30 KST  ags14  dvdrental  SELECT  READ
# 5     2024-02-21 09:08:30 KST  ags14  dvdrental  SELECT  READ
# 6     2024-02-21 09:08:30 KST  ags14  dvdrental  SELECT  READ
# ...                       ...    ...        ...     ...   ...
# 5623  2024-02-21 14:00:17 KST  ags14  dvdrental  SELECT  READ
# 5624  2024-02-21 14:00:17 KST  ags14  dvdrental  SELECT  READ
# 5625  2024-02-21 14:00:17 KST  ags14  dvdrental  SELECT  READ
# 5626  2024-02-21 14:00:17 KST  ags14  dvdrental  SELECT  READ
# 5627  2024-02-21 14:05:37 KST  ags14  dvdrental  SELECT  READ
#
#                                                      13
# 1     "SELECT tc.table_name,\n                      ...
# 3     "SELECT table_schema AS schema_name, table_nam...
# ...
